# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmdbnrsl/Machine-Learning/blob/main/Mathematics-Requirements/Maths_Random/End_of_Ramadhan_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $$\textbf{End of Ramadan Challenge}$$
#
# $\text{Do the questions below correctly, and get the THR.}$

# %% [markdown]
# $$\begin{aligned}
# & \mathcal{W}(x) = 1 + \sum_{i=1}^{2^x}\left\lfloor\left(\frac{x}{\sum_{j=1}^i \left\lfloor\cos^2\left(\pi\frac{(j - 1)! + 1}{j}\right)\right\rfloor}\right)^{\frac{1}x}\right\rfloor\\
# & \mathcal{s} = \Phi\left(\text{Sol}_x\left\{\mathcal{W}(x) =  \text{Sol}_{a^{+}}\left\{\frac{a^2 + 36}{5} = \mathcal{W}(7)\right\}\right\}\right)\\
# & \mathcal{A} = \left(\begin{matrix}\mathcal{s} & \mathcal{s} + \frac{1}{2} & \frac{6}{\mathcal{s}}\\2\mathcal{s} & 5\mathcal{s} & 2\mathcal{s}^2\\\sqrt{50\mathcal{s}} & \frac{5^{\mathcal{s}}}{\mathcal{s}} & 10\mathcal{s}\end{matrix}\right)\\
# & \mathcal{Y} = \mathcal{W}\left(\mathcal{W}\left(\prod\text{Sol}_{\lambda}\left\{\det(\mathcal{A} - \lambda I) = 0\right\}\right)\right)\\
# & z = \frac{\text{H}^2 + 9\text{u}^4}{\text{H}^2\text{u}^2 - 3\text{Hu}^4i}\\
# & \mathcal{S} = \sum_{k = 0}^{\infty}\left(\sum_{l = 0}^{\infty} \cos^l\left(\frac{\pi}{\text{Im}(z)\text{H}}\right)\right)\cdot\mathbb{1}_{\{k = 0\}}+ \sin^k\left(\frac{1}{\pi}\sum_{v = 1}^{\infty}\frac{1}{v^2}\right)\cdot \mathbb{1}_{\neg\{k = 0\}}\\
# & \mathcal{L} = \lim_{x \to \text{I}}\frac{\text{I}(\text{I}x - \text{I}e^{i\pi}x - \text{I}^2 + \text{I}^2e^{i\pi})}{(1 - e^{2i\pi}) + (x - \text{I})(x + \text{I})}
# \end{aligned}$$

# %% [markdown]
# $\text{Given the array below, index starts from 1.}$

# %%
# !pip install sympy
import sympy as sp
J = [sp.Symbol(chr(i)) for i in range(97, 123)]

# %% [markdown]
# $$\begin{aligned}
# & \gamma = \frac{\Gamma(\mathcal{W}(\lfloor\pi\rfloor))}{\lfloor\pi\lfloor e\rfloor\rfloor},\ \alpha = \text{B}\left(\lceil \pi \rceil\cos\left(\frac{\pi}{\lfloor \pi \rfloor}\right), \lceil e \rceil\right)^{-1}\\
# & \mathcal{M} = \frac{d}{d\text{t}}\left(\frac{\text{t}^{\lfloor \pi \rfloor}}{\lceil e \rceil}\right)\frac{d}{d\text{F}}(\ln(\text{F}))\frac{9\text{F}^{\mathcal{W}(1)}\text{r}^2 + \frac{30^2}{\text{t}^{\lfloor e \rfloor}}}{9 \text{tr} - \frac{90}{\text{F}}i}
# \end{aligned}$$
#
# prove that
# $$\begin{aligned}
# & \frac{-\text{Re}(\mathcal{M})}{\mathcal{Y}} = \frac{\mathcal{S}\text{Im}(z)^{-1}}{\mathcal{L}\text{J}_{\gamma}\text{J}_{\alpha}}\left(\int i^{\ln\left(\left(e\cos\left(i + \frac{1}{i}\right)\right)^2\right)}\cdot\text{Re}(z)\ d\text{u} - C\right)\\
# \end{aligned}$$
#
# is equal to
#
# $$\text{Idul Fitri} = 1447 \text{ H}$$

# %% [markdown]
# $$\textbf{Assignment Submission Terms}$$
#
# - The task is done independently, without the help of AI or other people or social media.
# - You have previously prepared your recording while working on this task. The recording may not be edited or cut.
# - Send your recording to ahmadbenirusli@gmail.com
# - The 2 fastest winners, the last submission date is March 23, 2026.
# - First people who collect assignments correctly and meet the work criteria will get a prize of 100 thousand rupiah, and second people will get 50 thousand rupiah.
